# %% [markdown]
# <div style="text-align: center;">
#     <img src="Banner.png" alt="image.png">
# </div>

# %% [markdown]
# <div style="text-align: center;">
#     <strong>PRECIPITACIÓN🌧️ EN COORDENADAS POLARES🌐</strong><br>
# </div>

# %%
from funciones import graficar_boxplot_polar, ensofuc
import pandas as pd
datos = pd.read_csv('C:/Users/Camilo/Desktop/TALLER 4/Vector.csv', delimiter=';')

# %%
# Definir columna de datos
nombre_columna='Pptn1m [mm]'
variable = 'Precipitacion'
unidades = 'mm'
# Llamar a las funciones
graficar_boxplot_polar(datos, nombre_columna, variable, unidades)

# %% [markdown]
# <div style="text-align: center;">
#     <strong>CICLO ANUAL CON ENSO</strong><br>
# </div>

# %%
enso=pd.read_excel("C:/Users/Camilo/Desktop/TALLER 4/Vector_ENSO.xlsx")
ensofuc(datos, nombre_columna, variable, unidades,enso)
